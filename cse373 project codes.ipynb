# %% [markdown]
# #Dynamic average

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def bottom_up_rod_cutting(givenPriceList, lengthOfRod):
    optimalPriceList = [0]*(lengthOfRod+1)
    # whereToCut = [0]*(lengthOfRod+1)
    optimalPriceList[0] = 0

    for j in range(1, lengthOfRod+1):
        maximum_revenue = -1*INFINITY
        for i in range(1, j+1):
            if (maximum_revenue < givenPriceList[i] + optimalPriceList[j-i]):
                maximum_revenue = givenPriceList[i] + optimalPriceList[j-i]
                # whereToCut[j] = i
        optimalPriceList[j] = maximum_revenue

if __name__ == '__main__':
    
    input_sizes = list(range(100, 10001, 1000))  # List of input sizes (amounts)
    execution_times = []

    for lengthOfRod in input_sizes:
        givenPriceList = [random.randint(1, lengthOfRod) for _ in range(lengthOfRod)]  # Generate random price list
        start_time = time.time()
        bottom_up_rod_cutting(givenPriceList, lengthOfRod-1)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting dynamic algorithm average case time complexity')
    plt.show()

# %% [markdown]
# #Dynamic Worst

# %%
import random
import time
import matplotlib.pyplot as plt
import math

INFINITY = 100000

def maximum(x, y):
    if x > y:
        return x
    return y

def fill_array_decreasing(size):
    arr = []
    for num in range(size, 0, -1):
        arr.append(num)
    return arr

def bottom_up_rod_cutting(givenPriceList, lengthOfRod):
    optimalPriceList = [0]*(lengthOfRod+1)
    whereToCut = [0]*(lengthOfRod+1)
    optimalPriceList[0] = 0

    for j in range(1, lengthOfRod+1):
        maximum_revenue = -1*INFINITY
        for i in range(1, j+1):
            if (maximum_revenue < givenPriceList[i] + optimalPriceList[j-i]):
                maximum_revenue = givenPriceList[i] + optimalPriceList[j-i]
                whereToCut[j] = i
        optimalPriceList[j] = maximum_revenue

if __name__ == '__main__':
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(1000, 50001, 5000):
        givenPriceList = fill_array_decreasing(lengthOfRod)  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        # print(givenPriceList)
        start_time = time.time()
        bottom_up_rod_cutting(givenPriceList, lengthOfRod)
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)

    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting dynamic algorithm worst case time complexity')
    plt.show()

# %% [markdown]
# #Dynamic Best

# %%
import random
import time
import matplotlib.pyplot as plt
import math

INFINITY = 100000

def maximum(x, y):
    if x > y:
        return x
    return y

def fill_array_increasing(size):
    arr = []
    for num in range(1, size + 1):
        arr.append(num)
    return arr

def bottom_up_rod_cutting(givenPriceList, lengthOfRod):
    optimalPriceList = [0]*(lengthOfRod+1)
    whereToCut = [0]*(lengthOfRod+1)
    optimalPriceList[0] = 0

    for j in range(1, lengthOfRod+1):
        maximum_revenue = -1*INFINITY
        for i in range(1, j+1):
            if (maximum_revenue < givenPriceList[i] + optimalPriceList[j-i]):
                maximum_revenue = givenPriceList[i] + optimalPriceList[j-i]
                whereToCut[j] = i
        optimalPriceList[j] = maximum_revenue

if __name__ == '__main__':
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(100, 10001, 100):
        givenPriceList = [1 for _ in range(lengthOfRod)]  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        # print(givenPriceList)
        start_time = time.time() 
        bottom_up_rod_cutting(givenPriceList, 0)
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)

    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    # current_values = plt.gca().get_yticks()
    # plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
    plt.ylim(-20, 20)
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting dynamic algorithm best case time complexity')
    plt.show()

# %% [markdown]
# #Bruteforce average

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def top_down_rod_cutting(givenPriceList, lengthOfRod):
    if (lengthOfRod == 0):
        return 0
    maximum_revenue = -1*INFINITY
    for i in range(1, lengthOfRod+1):
        maximum_revenue = max(maximum_revenue, givenPriceList[i] + top_down_rod_cutting(givenPriceList, lengthOfRod - i))
    return maximum_revenue

if __name__ == '__main__':
    # givenPriceList = [0, 1, 5, 8, 9, 10, 17, 17, 20, 24, 30]
    # lengthOfRod = 9
    # bottom_up_rod_cutting(givenPriceList, lengthOfRod)
    
    input_sizes = list(range(1, 31, 3))  # List of input sizes (amounts)
    execution_times = []

    for lengthOfRod in input_sizes:
        givenPriceList = [random.randint(1, lengthOfRod) for _ in range(lengthOfRod)]  # Generate random price list
        start_time = time.time()
        top_down_rod_cutting(givenPriceList, lengthOfRod-1)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    current_values = plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting bruteforce algorithm average case time complexity')
    plt.show()
# Out:
# <ipython-input-38-06d86e2392fa>:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])

# %% [markdown]
# #bruteforce worst

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def top_down_rod_cutting(givenPriceList, lengthOfRod):
    if (lengthOfRod == 0):
        return 0
    maximum_revenue = -1*INFINITY
    for i in range(1, lengthOfRod+1):
        maximum_revenue = max(maximum_revenue, givenPriceList[i] + top_down_rod_cutting(givenPriceList, lengthOfRod - i))
    return maximum_revenue

if __name__ == '__main__':
    
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(1, 31, 3):
        givenPriceList = fill_array_decreasing(lengthOfRod)  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        start_time = time.time()
        top_down_rod_cutting(givenPriceList, lengthOfRod-1)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    current_values = plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting bruteforce algorithm worst case time complexity')
    plt.show()
# Out:
# <ipython-input-92-b78636771852>:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])

# %% [markdown]
# #bruteforce best

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def top_down_rod_cutting(givenPriceList, lengthOfRod):
    if (lengthOfRod == 0):
        return 0
    maximum_revenue = -1*INFINITY
    for i in range(1, lengthOfRod+1):
        maximum_revenue = max(maximum_revenue, givenPriceList[i] + top_down_rod_cutting(givenPriceList, lengthOfRod - i))
    return maximum_revenue

if __name__ == '__main__':
    # givenPriceList = [0, 1, 5, 8, 9, 10, 17, 17, 20, 24, 30]
    # lengthOfRod = 9
    # bottom_up_rod_cutting(givenPriceList, lengthOfRod)
    
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(1, 31, 3):
        givenPriceList = [1 for _ in range(lengthOfRod)]  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        start_time = time.time()
        top_down_rod_cutting(givenPriceList, 0)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    # current_values = plt.gca().get_yticks()
    # plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.ylim(-50, 50)
    # plt.xlim(0,10)
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting bruteforce algorithm best case time complexity')
    plt.show()

# %% [markdown]
# #memoized average

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def memoized_recursive_rod_cutting(givenPriceList, lengthOfRod):
    memoOfPrices = [0]*(lengthOfRod+1)
    for i in range(1, lengthOfRod+1):
        memoOfPrices[i] = -1*INFINITY
    return mrrc(givenPriceList, lengthOfRod, memoOfPrices) #memo = optimal price

def mrrc(givenPriceList, lengthOfRod, memoOfPrices):
    if memoOfPrices[lengthOfRod] >= 0:
        return memoOfPrices[lengthOfRod]
    if lengthOfRod == 0:
        return 0
    else:
        maximum_revenue = -1*INFINITY
        for i in range(1, lengthOfRod+1):
            maximum_revenue = max(maximum_revenue, givenPriceList[i] + mrrc(givenPriceList, lengthOfRod-i, memoOfPrices))
        memoOfPrices[lengthOfRod] = maximum_revenue
        return memoOfPrices[lengthOfRod]

if __name__ == '__main__':
    # givenPriceList = [0, 1, 5, 8, 9, 10, 17, 17, 20, 24, 30]
    # lengthOfRod = 9
    # bottom_up_rod_cutting(givenPriceList, lengthOfRod)
    
    input_sizes = list(range(1, 1001, 100))  # List of input sizes (amounts)
    execution_times = []

    for lengthOfRod in input_sizes:
        givenPriceList = [random.randint(1, lengthOfRod) for _ in range(lengthOfRod)]  # Generate random price list
        start_time = time.time()
        memoized_recursive_rod_cutting(givenPriceList, lengthOfRod-1)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    current_values = plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting memoized recursion algorithm average case time complexity')
    plt.show()
# Out:
# <ipython-input-76-f0bc21b9ea51>:50: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])

# %% [markdown]
# #memoized worst

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def memoized_recursive_rod_cutting(givenPriceList, lengthOfRod):
    memoOfPrices = [0]*(lengthOfRod+1)
    for i in range(1, lengthOfRod+1):
        memoOfPrices[i] = -1*INFINITY
    return mrrc(givenPriceList, lengthOfRod, memoOfPrices)

def mrrc(givenPriceList, lengthOfRod, memoOfPrices):
    if memoOfPrices[lengthOfRod] >= 0:
        return memoOfPrices[lengthOfRod]
    if lengthOfRod == 0:
        return 0
    else:
        maximum_revenue = -1*INFINITY
        for i in range(1, lengthOfRod+1):
            maximum_revenue = max(maximum_revenue, givenPriceList[i] + mrrc(givenPriceList, lengthOfRod-i, memoOfPrices))
        memoOfPrices[lengthOfRod] = maximum_revenue
        return memoOfPrices[lengthOfRod]

if __name__ == '__main__':
    
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(1, 1001, 100):
        givenPriceList = fill_array_decreasing(lengthOfRod)  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        start_time = time.time()
        memoized_recursive_rod_cutting(givenPriceList, lengthOfRod-1)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    current_values = plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting memoized recursion algorithm worst case time complexity')
    plt.show()
# Out:
# <ipython-input-85-635061b49ec6>:49: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])

# %% [markdown]
# #memoized best

# %%
import random
import time
import matplotlib.pyplot as plt

INFINITY = 100000

def max(x, y):
    if x > y:
        return x
    return y

def memoized_recursive_rod_cutting(givenPriceList, lengthOfRod):
    memoOfPrices = [0]*(lengthOfRod+1)
    for i in range(1, lengthOfRod+1):
        memoOfPrices[i] = -1*INFINITY
    return mrrc(givenPriceList, lengthOfRod, memoOfPrices)

def mrrc(givenPriceList, lengthOfRod, memoOfPrices):
    if memoOfPrices[lengthOfRod] >= 0:
        return memoOfPrices[lengthOfRod]
    if lengthOfRod == 0:
        return 0
    else:
        maximum_revenue = -1*INFINITY
        for i in range(1, lengthOfRod+1):
            maximum_revenue = max(maximum_revenue, givenPriceList[i] + mrrc(givenPriceList, lengthOfRod-i, memoOfPrices))
        memoOfPrices[lengthOfRod] = maximum_revenue
        return memoOfPrices[lengthOfRod]

if __name__ == '__main__':
    
    input_sizes = list()
    execution_times = []

    for lengthOfRod in range(1, 1001, 100):
        givenPriceList = [1 for _ in range(lengthOfRod)]  # Corrected the range of exponentiation
        givenPriceList.insert(0, 0)
        input_sizes.append(len(givenPriceList))
        start_time = time.time()
        memoized_recursive_rod_cutting(givenPriceList, 0)  # Compute the optimal price for a length
        end_time = time.time()
        execution_time = end_time - start_time
        execution_times.append(execution_time)
        
    
    # Plot the graph
    plt.plot(input_sizes, execution_times, marker='o')
    current_values = plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
    plt.ylim(-20, 20)
    plt.xlabel('Input Size (Amount)')
    plt.ylabel('Execution Time (Seconds)')
    plt.title('Rod cutting memoized recursion algorithm best case time complexity')
    plt.show()
# Out:
# <ipython-input-94-a56b6280a1c9>:49: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.3f}'.format(x) for x in current_values])
